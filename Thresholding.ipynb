# %%
from skimage import data
import numpy as np
import matplotlib.pyplot as plt
import skimage.segmentation as seg
import skimage.filters as filters
import skimage.draw as draw
import skimage.color as color
from skimage.util import img_as_float

# %%
from skimage import io
image = io.imread('IMAGE.png') 
plt.imshow(image);

# %%
def image_show(image, nrows=1, ncols=1, cmap='gray'):
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(14, 14))
    ax.imshow(image, cmap='gray')
    ax.axis('off')
    return fig, ax

# %%
fig, ax = plt.subplots(1, 1)
ax.hist(image.ravel(), bins=32, range=[0, 256])
ax.set_xlim(0, 256);

# %%
image_segmented = image>50
image_segmented = img_as_float(image_segmented)


image_show(image_segmented);

# %%
image_segmented = image>10
image_segmented = img_as_float(image_segmented)


image_show(image_segmented);

# %%
image_segmented = image> 150
image_segmented = img_as_float(image_segmented)


image_show(image_segmented);

# %%
# segmenting leaves and grass
image_segmented = image>240
image_segmented = img_as_float(image_segmented)


image_show(image_segmented);
